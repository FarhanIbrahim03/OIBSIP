# %% [markdown]
# # Task-3 Sales prediction using python

# %% [markdown]
# Farhan M

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
#importing dataset

dat=pd.read_csv('C:/Users/Farhan/Documents/python jupyter/Datasets/Advertising.csv')
dat.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
#seems like unnamed column doesnt provide any significance so we will drop it
dat_new=dat.drop('Unnamed: 0',axis=1)
dat_new
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
dat_new.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   14.022500
# std     85.854236   14.846809   21.778621    5.217457
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   10.375000
# 50%    149.750000   22.900000   25.750000   12.900000
# 75%    218.825000   36.525000   45.100000   17.400000
# max    296.400000   49.600000  114.000000   27.000000

# %%
dat_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
#visualising

sns.heatmap(dat_new.corr(),annot=True)
# Out:
# <Axes: >

# %%
sns.distplot(dat_new["TV"])
# Out:
# C:\Users\Farhan\AppData\Local\Temp\ipykernel_14852\1953619365.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dat_new["TV"])
# <Axes: xlabel='TV', ylabel='Density'>

# %%
sns.distplot(dat_new["Newspaper"])
# Out:
# C:\Users\Farhan\AppData\Local\Temp\ipykernel_14852\1633268068.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dat_new["Newspaper"])
# <Axes: xlabel='Newspaper', ylabel='Density'>

# %%
sns.distplot(dat_new["Radio"])
# Out:
# C:\Users\Farhan\AppData\Local\Temp\ipykernel_14852\1034195202.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dat_new["Radio"])
# <Axes: xlabel='Radio', ylabel='Density'>

# %%
#splitting data

x=dat_new.iloc[:,:-1]
y=dat_new.iloc[:,-1]

# %%
x
# Out:
#         TV  Radio  Newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns]

# %%
y
# Out:
# 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
#        ...
# 195     7.6
# 196     9.7
# 197    12.8
# 198    25.5
# 199    13.4
# Name: Sales, Length: 200, dtype: float64

# %%
#ml model

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=50)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[63], line 6
#       3 x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=50)
#       4 from sklearn.metrics import r2_score
# ----> 6 r2_score(y_pred,y_train)
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:211, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     205 try:
#     206     with config_context(
#     207         skip_parameter_validation=(
#     208             prefer_skip_nested_validation or global_skip_validation
#     209         )
#     210     ):
# --> 211         return func(*args, **kwargs)
#     212 except InvalidParameterError as e:
#     213     # When the function is just a wrapper around an estimator, we allow
#     214     # the function to delegate validation to the estimator, but we replace
# ...

# %%
lr=LinearRegression()

lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)
y_pred
# Out:
# array([13.86471261, 15.0090562 , 10.60511722, 10.09061905, 10.2058302 ,
#        18.44112845, 15.35623109,  3.50456716, 20.57163267, 11.98288476,
#        15.08601123, 12.84835102, 21.13029782, 14.37916353, 15.96630443,
#        16.97004665, 10.28916068, 16.78706185,  9.5680503 , 12.51794578,
#        16.90028224, 10.16656637,  8.06620555, 13.98212973, 21.32738303,
#        14.23529429,  7.20839801,  7.55987252, 15.4385442 , 13.60561012,
#        14.89945663, 10.22068212, 11.980595  , 16.40933006,  6.58023303,
#         9.63142726, 12.99984158, 20.51038927,  9.15336417, 11.31226434,
#         7.30108894, 24.61494601,  9.80946097, 18.27320104, 16.57103149,
#        12.0584219 , 12.43507395, 16.11514576,  8.76566004,  7.84595288,
#        12.21810153, 12.07628047, 14.37606032, 10.49776835, 17.58332133,
#        16.68505237, 16.43189148,  3.56597841, 23.2024176 , 13.2715782 ])

# %%
#metricsabs
from sklearn.metrics import r2_score

r2_score(y_pred,y_test)
# Out:
# 0.8684089550571558

# %%
figsize=(30, 30)

ax1 = sns.distplot(dat_new['Sales'], hist=False, color="r", label="Actual Value")
sns.distplot(y_pred, hist=False, color="g", label="Fitted Values" , ax=ax1);

plt.title('Actual vs Fitted Values for Price')
plt.legend()
plt.show()
# Out:
# C:\Users\Farhan\AppData\Local\Temp\ipykernel_14852\3157928423.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax1 = sns.distplot(dat_new['Sales'], hist=False, color="r", label="Actual Value")
# C:\Users\Farhan\AppData\Local\Temp\ipykernel_14852\3157928423.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
#a prediction
inputdat=np.array([180.8,10.8,58.4])
inputdat= inputdat.reshape(1,-1)
lr.predict(inputdat)
# Out:
# C:\Users\Farhan\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([13.62786027])
